# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datasets import load_dataset

# %%
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

# %%
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# 780907              Data Engineer with Fivetran,Qlik Must
#
#                      job_location                 job_via job_schedule_type  \
# 502901                St Paul, MN               via BeBee         Full-time
# 406337                 London, UK            via LinkedIn         Full-time
# 659951    Newcastle upon Tyne, UK              via Indeed         Full-time
# 541593                      Malta         via Trabajo.org         Full-time
# 425158     Amsterdam, Netherlands          via NBC4i Jobs         Full-time
# 183426                  Singapore  via Singapore | JobsDB         Full-time
# 287790                  Tampa, FL            via LinkedIn         Full-time
# 541983              Chantilly, VA      via Clearance Jobs         Full-time
# 416896                     France            via LinkedIn         Full-time
# 780907  Mexico City, CDMX, Mexico        via BeBee México         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
# 183426               False               Singapore 2023-11-09 16:07:57
# 287790               False  Florida, United States 2023-07-14 17:02:23
# 541983               False                 Georgia 2023-06-15 19:44:34
# 416896               False                  France 2023-09-22 16:47:24
# 780907               False                  Mexico 2023-01-16 06:19:09
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
# 183426                  False                 False       Singapore
# 287790                   True                 False   United States
# 541983                  False                 False   United States
# 416896                  False                 False          France
# 780907                  False                 False          Mexico
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
# 183426        None              NaN              NaN    FLEXOSENSE PTE. LTD.
# 287790        None              NaN              NaN      Iris Software Inc.
# 541983        None              NaN              NaN                    SAIC
# 416896        None              NaN              NaN             KPMG France
# 780907        None              NaN              NaN        CORUS Consulting
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
# 183426  ['r', 'python', 'java', 'sql', 'sql server', '...
# 287790                         ['sql', 'hadoop', 'excel']
# 541983  ['sql', 'r', 'matlab', 'python', 'oracle', 'aw...
# 416896                                               None
# 780907  ['oracle', 'snowflake', 'aws', 'azure', 'alter...
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
# 183426  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 287790  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 541983  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 416896                                               None
# 780907  {'analyst_tools': ['alteryx'], 'cloud': ['orac...

# %%
df_original=dataset['train'].to_pandas()

# %%
df_altered=df_original.copy()

# %%
id(df_original)
# Out:
# 3027825149808

# %%
id(df_altered)
# Out:
# 3027825150720

# %%
df.sample(frac=0.1)
# Out:
#               job_title_short  \
# 290243           Data Analyst
# 186306      Software Engineer
# 358819         Data Scientist
# 300848          Data Engineer
# 640165         Data Scientist
# ...                       ...
# 407321          Data Engineer
# 154876         Data Scientist
# 462870  Senior Data Scientist
# 317148           Data Analyst
# 124751          Data Engineer
#
#                                                 job_title  \
# 290243                  Business und Data Analyst (m/w/d)
# 186306                                    DevOps Engineer
# 358819                         Data scientist sql data or
# 300848             BUSINESS DATA ANALYST/ENGINEER (m/w/d)
# 640165                                Data Scientist Lead
# ...                                                   ...
# 407321                                 Lead Data Engineer
# 154876                                 Hiring for Analyst
# 462870                 Consultant Senior Data Science H/F
# 317148  Data Analyst. Job in Schaffhausen LilyLifestyl...
# 124751                【US Fintech】Bilingual Data Engineer
#
#                                              job_location  \
# 290243                                        Switzerland
# 186306                            Canberra ACT, Australia
# 358819                                        Chicago, IL
# 300848                                   Dresden, Germany
# 640165                                         Dallas, TX
# ...                                                   ...
# 407321                                   NEWCOMB HALL, VA
# 154876  Kuala Lumpur, Federal Territory of Kuala Lumpu...
# 462870                                      Paris, France
# 317148                          Schaffhausen, Switzerland
# 124751                                           Anywhere
#
#                        job_via        job_schedule_type  job_work_from_home  \
# 290243              via Indeed                Full-time               False
# 186306         via Trabajo.org                Full-time               False
# 358819               via BeBee                Full-time               False
# 300848            via LinkedIn                Full-time               False
# 640165         via Trabajo.org                Full-time               False
# ...                        ...                      ...                 ...
# 407321            via LifeworQ  Full-time and Part-time               False
# 154876      via BeBee Malaysia                Full-time               False
# 462870           via HelloWork                Full-time               False
# 317148  via LilyLifestyle Jobs                Full-time               False
# 124751            via LinkedIn                Full-time                True
#
#                 search_location     job_posted_date  job_no_degree_mention  \
# 290243              Switzerland 2023-06-27 17:40:14                   True
# 186306                Australia 2023-05-04 15:22:47                   True
# 358819  Illinois, United States 2023-10-13 23:04:13                  False
# 300848                  Germany 2023-04-14 17:50:27                   True
# 640165                    Sudan 2023-03-12 12:30:48                  False
# ...                         ...                 ...                    ...
# 407321  New York, United States 2023-12-05 16:04:58                  False
# 154876                 Malaysia 2023-03-30 08:13:27                   True
# 462870                   France 2023-01-19 14:56:44                  False
# 317148              Switzerland 2023-03-15 17:20:13                   True
# 124751                    Japan 2023-09-05 08:53:05                   True
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 290243                 False    Switzerland        None              NaN
# 186306                 False      Australia        None              NaN
# 358819                 False  United States        None              NaN
# 300848                 False        Germany        None              NaN
# 640165                 False          Sudan        None              NaN
# ...                      ...            ...         ...              ...
# 407321                  True  United States        year         179000.0
# 154876                 False       Malaysia        None              NaN
# 462870                 False         France        None              NaN
# 317148                 False    Switzerland        None              NaN
# 124751                 False          Japan        None              NaN
#
#         salary_hour_avg                      company_name  \
# 290243              NaN       COMPEGAS HR Management GmbH
# 186306              NaN                           Datacom
# 358819              NaN     Advent Global Solutions, Inc.
# 300848              NaN                 Fortuneglobe GmbH
# 640165              NaN                             Wipro
# ...                 ...                               ...
# 407321              NaN                       Capital One
# 154876              NaN  Standard Chartered Bank Malaysia
# 462870              NaN                      Sia Partners
# 317148              NaN                              GITR
# 124751              NaN       スキルハウス・スタッフィング・ソリューションズ株式会社
#
#                                                job_skills  \
# 290243                            ['sql', 'vba', 'excel']
# 186306  ['powershell', 'javascript', 'python', 'aws', ...
# 358819  ['sql', 'python', 'java', 'scala', 'perl', 'r'...
# 300848          ['sql', 'python', 'php', 'excel', 'qlik']
# 640165  ['python', 'git', 'github', 'jenkins', 'terraf...
# ...                                                   ...
# 407321                                    ['aws', 'jira']
# 154876  ['java', 'shell', 'oracle', 'sharepoint', 'jen...
# 462870  ['python', 'r', 'sas', 'sas', 'matlab', 'javas...
# 317148     ['go', 'python', 'spreadsheet', 'git', 'jira']
# 124751                          ['sql', 'python', 'flow']
#
#                                           job_type_skills
# 290243  {'analyst_tools': ['excel'], 'programming': ['...
# 186306  {'cloud': ['aws', 'vmware'], 'os': ['windows',...
# 358819  {'libraries': ['hadoop', 'spark'], 'programmin...
# 300848  {'analyst_tools': ['excel', 'qlik'], 'programm...
# 640165  {'other': ['git', 'github', 'jenkins', 'terraf...
# ...                                                   ...
# 407321              {'async': ['jira'], 'cloud': ['aws']}
# 154876  {'analyst_tools': ['sharepoint'], 'async': ['j...
# 462870  {'analyst_tools': ['sas'], 'cloud': ['azure'],...
# 317148  {'analyst_tools': ['spreadsheet'], 'async': ['...
# 124751  {'other': ['flow'], 'programming': ['sql', 'py...
#
# [78574 rows x 17 columns]
